# %% [markdown]
# imports

# %%
import seaborn as sns

# %%
sns.get_dataset_names() # To check different datasets in seaborn
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset("flights")
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = sns.load_dataset("flights")

# %% [markdown]
# line chart

# %%
sns.lineplot(data=flights,
            x="year",
            y="passengers",
            errorbar=None,
            hue="month",
            #hue="year"
            )
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# Barchart

# %%
# 1. Vertical Barchart

sns.barplot(data=flights,
            x="month",
            y="passengers",
            errorbar=None,
            estimator="sum")
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
# 2. Horizontal Barchart

sns.barplot(data=flights,
            y="month",
            x="passengers",
            errorbar=None,
            estimator="sum", orient="y")

            # Result: Transpose the visualizationo of the data
# Out:
# <Axes: xlabel='passengers', ylabel='month'>

# %% [markdown]
# Scatter plot: Heavily used when we want to compare different information

# %%
sns.scatterplot(data=flights,
                x="year",
                y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
#  Heatmaps
#
#  Mostly use in corrilation of data

# %%
sns.heatmap(flights.pivot(index="year", columns="month", values="passengers"),
cmap="crest")
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %% [markdown]
# Histogram

# %%
sns.histplot(data=flights,
             x="passengers")
# Out:
# <Axes: xlabel='passengers', ylabel='Count'>

# %%
sns.histplot(data=flights,
             x="passengers",
             bins=30,
             kde=True) #kde= smootline related to bar
# Out:
# <Axes: xlabel='passengers', ylabel='Count'>

# %%
sns.histplot(data=flights,
             x="passengers",
             bins=30,
             hue="month",
             multiple="stack")
# Out:
# <Axes: xlabel='passengers', ylabel='Count'>

# %% [markdown]
# Boxplot/Violin

# %%
sns.boxplot(data=flights,
             y="passengers"
             #x="year"
             )
# Out:
# <Axes: ylabel='passengers'>

# %%
sns.boxplot(data=flights,
             y="passengers",
             x="year"
             )
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
#Violin

sns.violinplot(data=flights,
                y="passengers")
# Out:
# <Axes: ylabel='passengers'>

# %%
sns.violinplot(data=flights,
                y="passengers",
                x="year")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>
